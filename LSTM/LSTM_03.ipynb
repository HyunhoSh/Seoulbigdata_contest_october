# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import folium
plt.rcParams["font.family"] = "NanumGothic"
plt.rcParams["figure.figsize"] = (10,10)

ppl = pd.read_csv('C:\\신현호\\2021_2학기_공모전\\코드구성\\서울시_인구수_예측\\ppl.csv',encoding='cp949')
ppl
# Out:
#       Unnamed: 0    구     인구수       년월
# 0              0  종로구  154619  2018-01
# 1              1   중구  125786  2018-01
# 2              2  용산구  229541  2018-01
# 3              3  성동구  304955  2018-01
# 4              4  광진구  357785  2018-01
# ...          ...  ...     ...      ...
# 2195        2196  관악구  488525  2021-07
# 2196        2197  서초구  418294  2021-07
# 2197        2198  강남구  530529  2021-07
# 2198        2199  송파구  658093  2021-07
# 2199        2200  강동구  465191  2021-07
#
# [2200 rows x 4 columns]

# %%
ppl = ppl.drop(columns = 'Unnamed: 0',axis=1)
ppl
# Out:
#         구     인구수       년월
# 0     종로구  154619  2018-01
# 1      중구  125786  2018-01
# 2     용산구  229541  2018-01
# 3     성동구  304955  2018-01
# 4     광진구  357785  2018-01
# ...   ...     ...      ...
# 2195  관악구  488525  2021-07
# 2196  서초구  418294  2021-07
# 2197  강남구  530529  2021-07
# 2198  송파구  658093  2021-07
# 2199  강동구  465191  2021-07
#
# [2200 rows x 3 columns]

# %% [markdown]
# # 송파구

# %%
seocho = ppl[ppl['구'].str.contains('송파구')]
seocho = seocho.sort_values('년월')
seocho['년월'] = pd.to_datetime(seocho['년월'],format='%Y-%m')
seocho.set_index('년월',inplace=True)
seocho
# Out:
#               구     인구수
# 년월
# 2014-04-01  송파구  662947
# 2014-05-01  송파구  662649
# 2014-06-01  송파구  662325
# 2014-07-01  송파구  661742
# 2014-08-01  송파구  660595
# ...         ...     ...
# 2021-03-01  송파구  661411
# 2021-04-01  송파구  660160
# 2021-05-01  송파구  659446
# 2021-06-01  송파구  658670
# 2021-07-01  송파구  658093
#
# [88 rows x 2 columns]

# %%
seocho['인구수'].plot()
# Out:
# <AxesSubplot:xlabel='년월'>

# %%
split_date = pd.Timestamp('2019--11-01')

train = seocho.loc[:split_date, ['인구수']]
test = seocho.loc[split_date:, ['인구수']]

ax = train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test'])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train)
test_scaled = scaler.fit_transform(test)

# %%
train_scaled_df = pd.DataFrame(train_scaled, columns=['인구수'], index=train.index)
test_scaled_df = pd.DataFrame(test_scaled, columns=['인구수'], index=test.index)
train_scaled_df.head()
# Out:
#                  인구수
# 년월
# 2014-04-01  0.498903
# 2014-05-01  0.490064
# 2014-06-01  0.480454
# 2014-07-01  0.463163
# 2014-08-01  0.429143

# %%
for s in range(1, 13):
    train_scaled_df['{}'.format(s)] = train_scaled_df['인구수'].shift(s)
    test_scaled_df['{}'.format(s)] = test_scaled_df['인구수'].shift(s)
train_scaled_df
# Out:
#                  인구수         1         2         3         4         5  \
# 년월
# 2014-04-01  0.498903       NaN       NaN       NaN       NaN       NaN
# 2014-05-01  0.490064  0.498903       NaN       NaN       NaN       NaN
# 2014-06-01  0.480454  0.490064  0.498903       NaN       NaN       NaN
# 2014-07-01  0.463163  0.480454  0.490064  0.498903       NaN       NaN
# 2014-08-01  0.429143  0.463163  0.480454  0.490064  0.498903       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-07-01  0.961769  0.982353  1.000000  0.999466  0.960820  0.869735
# 2019-08-01  0.936529  0.961769  0.982353  1.000000  0.999466  0.960820
# 2019-09-01  0.930211  0.936529  0.961769  0.982353  1.000000  0.999466
# 2019-10-01  0.895776  0.930211  0.936529  0.961769  0.982353  1.000000
# 2019-11-01  0.881392  0.895776  0.930211  0.936529  0.961769  0.982353
#
#                    6         7         8         9        10        11  \
# 년월
# 2014-04-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-05-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-06-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-07-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-08-01       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-07-01  0.734547  0.608287  0.602236  0.612765  0.615909  0.623591
# 2019-08-01  0.869735  0.734547  0.608287  0.602236  0.612765  0.615909
# 2019-09-01  0.960820  0.869735  0.734547  0.608287  0.602236  0.612765
# 2019-10-01  0.999466  0.960820  0.869735  0.734547  0.608287  0.602236
# 2019-11-01  1.000000  0.999466  0.960820  0.869735  0.734547  0.608287
#
#                   12
# 년월
# 2014-04-01       NaN
# 2014-05-01       NaN
# 2014-06-01       NaN
# 2014-07-01       NaN
# 2014-08-01       NaN
# ...              ...
# 2019-07-01  0.623384
# 2019-08-01  0.623591
# 2019-09-01  0.615909
# 2019-10-01  0.612765
# 2019-11-01  0.602236
#
# [68 rows x 13 columns]

# %%
X_train = train_scaled_df.dropna().drop('인구수', axis=1)
y_train = train_scaled_df.dropna()[['인구수']]

X_test = test_scaled_df.dropna().drop('인구수', axis=1)
y_test = test_scaled_df.dropna()[['인구수']]

y_train
# Out:
#                  인구수
# 년월
# 2015-04-01  0.316704
# 2015-05-01  0.314865
# 2015-06-01  0.300006
# 2015-07-01  0.282329
# 2015-08-01  0.269130
# 2015-09-01  0.255546
# 2015-10-01  0.230662
# 2015-11-01  0.205629
# 2015-12-01  0.165975
# 2016-01-01  0.154051
# 2016-02-01  0.100605
# 2016-03-01  0.053328
# 2016-04-01  0.037252
# 2016-05-01  0.019160
# 2016-06-01  0.008928
# 2016-07-01  0.012457
# 2016-08-01  0.002017
# 2016-09-01  0.000000
# 2016-10-01  0.030342
# 2016-11-01  0.062730
# 2016-12-01  0.067505
# 2017-01-01  0.108494
# 2017-02-01  0.155327
# 2017-03-01  0.149781
# 2017-04-01  0.143967
# 2017-05-01  0.159242
# 2017-06-01  0.173449
# 2017-07-01  0.185609
# 2017-08-01  0.198926
# 2017-09-01  0.180182
# 2017-10-01  0.217701
# 2017-11-01  0.240361
# 2017-12-01  0.264474
# 2018-01-01  0.561810
# 2018-02-01  0.568069
# 2018-03-01  0.568158
# 2018-04-01  0.569255
# 2018-05-01  0.578182
# 2018-06-01  0.602474
# 2018-07-01  0.623384
# 2018-08-01  0.623591
# 2018-09-01  0.615909
# 2018-10-01  0.612765
# 2018-11-01  0.602236
# 2018-12-01  0.608287
# 2019-01-01  0.734547
# 2019-02-01  0.869735
# 2019-03-01  0.960820
# 2019-04-01  0.999466
# 2019-05-01  1.000000
# 2019-06-01  0.982353
# 2019-07-01  0.961769
# 2019-08-01  0.936529
# 2019-09-01  0.930211
# 2019-10-01  0.895776
# 2019-11-01  0.881392

# %%
y_test.index
# Out:
# DatetimeIndex(['2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01',
#                '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01',
#                '2021-07-01'],
#               dtype='datetime64[ns]', name='년월', freq=None)

# %%
X_train = X_train.values
X_test = X_test.values

y_train = y_train.values
y_test_ = y_test.values
X_train
# Out:
# array([[0.327352  , 0.32055997, 0.31210701, 0.31542888, 0.3451477 ,
#         0.36789655, 0.40823348, 0.42914343, 0.46316289, 0.48045438,
#         0.49006406, 0.4989026 ],
#        [0.31670424, 0.327352  , 0.32055997, 0.31210701, 0.31542888,
#         0.3451477 , 0.36789655, 0.40823348, 0.42914343, 0.46316289,
#         0.48045438, 0.49006406],
#        [0.31486535, 0.31670424, 0.327352  , 0.32055997, 0.31210701,
#         0.31542888, 0.3451477 , 0.36789655, 0.40823348, 0.42914343,
#         0.46316289, 0.48045438],
#        [0.30000593, 0.31486535, 0.31670424, 0.327352  , 0.32055997,
#         0.31210701, 0.31542888, 0.3451477 , 0.36789655, 0.40823348,
#         0.42914343, 0.46316289],
#        [0.28232886, 0.30000593, 0.31486535, 0.31670424, 0.327352  ,
#         0.32055997, 0.31210701, 0.31542888, 0.3451477 , 0.36789655,
#         0.40823348, 0.42914343],
#        [0.26913038, 0.28232886, 0.30000593, 0.31486535, 0.31670424,
#         0.327352  , 0.32055997, 0.31210701, 0.31542888, 0.3451477 ,
#         0.36789655, 0.40823348],
#        [0.25554633, 0.26913038, 0.28232886, 0.30000593, 0.31486535,
#         0.31670424, 0.327352  , 0.32055997, 0.31210701, 0.31542888,
#         0.3451477 , 0.36789655],
#        [0.230662  , 0.25554633, 0.26913038, 0.28232886, 0.30000593,
#         0.31486535, 0.31670424, 0.327352  , 0.32055997, 0.31210701,
#         0.31542888, 0.3451477 ],
#        [0.20562937, 0.230662  , 0.25554633, 0.26913038, 0.28232886,
#         0.30000593, 0.31486535, 0.31670424, 0.327352  , 0.32055997,
#         0.31210701, 0.31542888],
#        [0.16597461, 0.20562937, 0.230662  , 0.25554633, 0.26913038,
#         0.28232886, 0.30000593, 0.31486535, 0.31670424, 0.327352  ,
#         0.32055997, 0.31210701],
#        [0.15405149, 0.16597461, 0.20562937, 0.230662  , 0.25554633,
#         0.26913038, 0.28232886, 0.30000593, 0.31486535, 0.31670424,
#         0.327352  , 0.32055997],
#        [0.10060505, 0.15405149, 0.16597461, 0.20562937, 0.230662  ,
#         0.25554633, 0.26913038, 0.28232886, 0.30000593, 0.31486535,
#         0.31670424, 0.327352  ],
#        [0.0533278 , 0.10060505, 0.15405149, 0.16597461, 0.20562937,
#         0.230662  , 0.25554633, 0.26913038, 0.28232886, 0.30000593,
#         0.31486535, 0.31670424],
#        [0.03725234, 0.0533278 , 0.10060505, 0.15405149, 0.16597461,
#         0.20562937, 0.230662  , 0.25554633, 0.26913038, 0.28232886,
#         0.30000593, 0.31486535],
#        [0.01916004, 0.03725234, 0.0533278 , 0.10060505, 0.15405149,
#         0.16597461, 0.20562937, 0.230662  , 0.25554633, 0.26913038,
#         0.28232886, 0.30000593],
#        [0.00892751, 0.01916004, 0.03725234, 0.0533278 , 0.10060505,
#         0.15405149, 0.16597461, 0.20562937, 0.230662  , 0.25554633,
#         0.26913038, 0.28232886],
#        [0.01245699, 0.00892751, 0.01916004, 0.03725234, 0.0533278 ,
#         0.10060505, 0.15405149, 0.16597461, 0.20562937, 0.230662  ,
#         0.25554633, 0.26913038],
#        [0.00201685, 0.01245699, 0.00892751, 0.01916004, 0.03725234,
#         0.0533278 , 0.10060505, 0.15405149, 0.16597461, 0.20562937,
#         0.230662  , 0.25554633],
#        [0.        , 0.00201685, 0.01245699, 0.00892751, 0.01916004,
#         0.03725234, 0.0533278 , 0.10060505, 0.15405149, 0.16597461,
#         0.20562937, 0.230662  ],
#        [0.03034168, 0.        , 0.00201685, 0.01245699, 0.00892751,
#         0.01916004, 0.03725234, 0.0533278 , 0.10060505, 0.15405149,
#         0.16597461, 0.20562937],
#        [0.06272986, 0.03034168, 0.        , 0.00201685, 0.01245699,
#         0.00892751, 0.01916004, 0.03725234, 0.0533278 , 0.10060505,
#         0.15405149, 0.16597461],
#        [0.06750504, 0.06272986, 0.03034168, 0.        , 0.00201685,
#         0.01245699, 0.00892751, 0.01916004, 0.03725234, 0.0533278 ,
#         0.10060505, 0.15405149],
#        [0.10849448, 0.06750504, 0.06272986, 0.03034168, 0.        ,
#         0.00201685, 0.01245699, 0.00892751, 0.01916004, 0.03725234,
#         0.0533278 , 0.10060505],
#        [0.15532685, 0.10849448, 0.06750504, 0.06272986, 0.03034168,
#         0.        , 0.00201685, 0.01245699, 0.00892751, 0.01916004,
#         0.03725234, 0.0533278 ],
#        [0.14978052, 0.15532685, 0.10849448, 0.06750504, 0.06272986,
#         0.03034168, 0.        , 0.00201685, 0.01245699, 0.00892751,
#         0.01916004, 0.03725234],
#        [0.14396726, 0.14978052, 0.15532685, 0.10849448, 0.06750504,
#         0.06272986, 0.03034168, 0.        , 0.00201685, 0.01245699,
#         0.00892751, 0.01916004],
#        [0.1592419 , 0.14396726, 0.14978052, 0.15532685, 0.10849448,
#         0.06750504, 0.06272986, 0.03034168, 0.        , 0.00201685,
#         0.01245699, 0.00892751],
#        [0.17344881, 0.1592419 , 0.14396726, 0.14978052, 0.15532685,
#         0.10849448, 0.06750504, 0.06272986, 0.03034168, 0.        ,
#         0.00201685, 0.01245699],
#        [0.18560921, 0.17344881, 0.1592419 , 0.14396726, 0.14978052,
#         0.15532685, 0.10849448, 0.06750504, 0.06272986, 0.03034168,
#         0.        , 0.00201685],
#        [0.19892633, 0.18560921, 0.17344881, 0.1592419 , 0.14396726,
#         0.14978052, 0.15532685, 0.10849448, 0.06750504, 0.06272986,
#         0.03034168, 0.        ],
#        [0.18018152, 0.19892633, 0.18560921, 0.17344881, 0.1592419 ,
#         0.14396726, 0.14978052, 0.15532685, 0.10849448, 0.06750504,
#         0.06272986, 0.03034168],
#        [0.21770079, 0.18018152, 0.19892633, 0.18560921, 0.17344881,
#         0.1592419 , 0.14396726, 0.14978052, 0.15532685, 0.10849448,
#         0.06750504, 0.06272986],
#        [0.24036066, 0.21770079, 0.18018152, 0.19892633, 0.18560921,
#         0.17344881, 0.1592419 , 0.14396726, 0.14978052, 0.15532685,
#         0.10849448, 0.06750504],
#        [0.26447384, 0.24036066, 0.21770079, 0.18018152, 0.19892633,
#         0.18560921, 0.17344881, 0.1592419 , 0.14396726, 0.14978052,
#         0.15532685, 0.10849448],
#        [0.56181042, 0.26447384, 0.24036066, 0.21770079, 0.18018152,
#         0.19892633, 0.18560921, 0.17344881, 0.1592419 , 0.14396726,
#         0.14978052, 0.15532685],
#        [0.56806857, 0.56181042, 0.26447384, 0.24036066, 0.21770079,
#         0.18018152, 0.19892633, 0.18560921, 0.17344881, 0.1592419 ,
#         0.14396726, 0.14978052],
#        [0.56815755, 0.56806857, 0.56181042, 0.26447384, 0.24036066,
#         0.21770079, 0.18018152, 0.19892633, 0.18560921, 0.17344881,
#         0.1592419 , 0.14396726],
#        [0.56925495, 0.56815755, 0.56806857, 0.56181042, 0.26447384,
#         0.24036066, 0.21770079, 0.18018152, 0.19892633, 0.18560921,
#         0.17344881, 0.1592419 ],
#        [0.57818247, 0.56925495, 0.56815755, 0.56806857, 0.56181042,
#         0.26447384, 0.24036066, 0.21770079, 0.18018152, 0.19892633,
#         0.18560921, 0.17344881],
#        [0.6024736 , 0.57818247, 0.56925495, 0.56815755, 0.56806857,
#         0.56181042, 0.26447384, 0.24036066, 0.21770079, 0.18018152,
#         0.19892633, 0.18560921],
#        [0.62338356, 0.6024736 , 0.57818247, 0.56925495, 0.56815755,
#         0.56806857, 0.56181042, 0.26447384, 0.24036066, 0.21770079,
#         0.18018152, 0.19892633],
#        [0.62359117, 0.62338356, 0.6024736 , 0.57818247, 0.56925495,
#         0.56815755, 0.56806857, 0.56181042, 0.26447384, 0.24036066,
#         0.21770079, 0.18018152],
#        [0.61590936, 0.62359117, 0.62338356, 0.6024736 , 0.57818247,
#         0.56925495, 0.56815755, 0.56806857, 0.56181042, 0.26447384,
#         0.24036066, 0.21770079],
#        [0.61276545, 0.61590936, 0.62359117, 0.62338356, 0.6024736 ,
#         0.57818247, 0.56925495, 0.56815755, 0.56806857, 0.56181042,
#         0.26447384, 0.24036066],
#        [0.60223633, 0.61276545, 0.61590936, 0.62359117, 0.62338356,
#         0.6024736 , 0.57818247, 0.56925495, 0.56815755, 0.56806857,
#         0.56181042, 0.26447384],
#        [0.60828687, 0.60223633, 0.61276545, 0.61590936, 0.62359117,
#         0.62338356, 0.6024736 , 0.57818247, 0.56925495, 0.56815755,
#         0.56806857, 0.56181042],
#        [0.7345474 , 0.60828687, 0.60223633, 0.61276545, 0.61590936,
#         0.62359117, 0.62338356, 0.6024736 , 0.57818247, 0.56925495,
#         0.56815755, 0.56806857],
#        [0.86973544, 0.7345474 , 0.60828687, 0.60223633, 0.61276545,
#         0.61590936, 0.62359117, 0.62338356, 0.6024736 , 0.57818247,
#         0.56925495, 0.56815755],
#        [0.96081979, 0.86973544, 0.7345474 , 0.60828687, 0.60223633,
#         0.61276545, 0.61590936, 0.62359117, 0.62338356, 0.6024736 ,
#         0.57818247, 0.56925495],
#        [0.99946613, 0.96081979, 0.86973544, 0.7345474 , 0.60828687,
#         0.60223633, 0.61276545, 0.61590936, 0.62359117, 0.62338356,
#         0.6024736 , 0.57818247],
#        [1.        , 0.99946613, 0.96081979, 0.86973544, 0.7345474 ,
#         0.60828687, 0.60223633, 0.61276545, 0.61590936, 0.62359117,
#         0.62338356, 0.6024736 ],
#        [0.98235259, 1.        , 0.99946613, 0.96081979, 0.86973544,
#         0.7345474 , 0.60828687, 0.60223633, 0.61276545, 0.61590936,
#         0.62359117, 0.62338356],
#        [0.96176889, 0.98235259, 1.        , 0.99946613, 0.96081979,
#         0.86973544, 0.7345474 , 0.60828687, 0.60223633, 0.61276545,
#         0.61590936, 0.62359117],
#        [0.93652865, 0.96176889, 0.98235259, 1.        , 0.99946613,
#         0.96081979, 0.86973544, 0.7345474 , 0.60828687, 0.60223633,
#         0.61276545, 0.61590936],
#        [0.93021118, 0.93652865, 0.96176889, 0.98235259, 1.        ,
#         0.99946613, 0.96081979, 0.86973544, 0.7345474 , 0.60828687,
#         0.60223633, 0.61276545],
#        [0.89577649, 0.93021118, 0.93652865, 0.96176889, 0.98235259,
#         1.        , 0.99946613, 0.96081979, 0.86973544, 0.7345474 ,
#         0.60828687, 0.60223633]])

# %%
X_train_t = X_train.reshape(X_train.shape[0], 12, 1)
X_test_t = X_test.reshape(X_test.shape[0], 12, 1)
X_train_t.shape
# Out:
# (56, 12, 1)

# %%
from keras.layers import LSTM 
from keras.models import Sequential 
from keras.layers import Dense 
import keras.backend as K 
from keras.callbacks import EarlyStopping

# %%
K.clear_session()
    
model = Sequential() # Sequeatial Model 
model.add(LSTM(20, input_shape=(12, 1))) # (timestep, feature) 
model.add(Dense(1)) # output = 1 
model.compile(loss='mean_squared_error', optimizer='adam') 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 20)                1760
# _________________________________________________________________
# dense (Dense)                (None, 1)                 21
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1)

model.fit(X_train_t, y_train, epochs=100,
          batch_size=30, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0355
# Epoch 2/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0341
# Epoch 3/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0325
# Epoch 4/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0316
# Epoch 5/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0313
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0311
# Epoch 7/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0305
# Epoch 8/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0300
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0293
# Epoch 10/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0285
# Epoch 11/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0278
# Epoch 12/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0272
# Epoch 13/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0268
# Epoch 14/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0265
# Epoch 15/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0262
# Epoch 16/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0258
# Epoch 17/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0255
# Epoch 18/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0252
# Epoch 19/100
# 2/2 [==============================] - ETA: 0s - loss: 0.020 - 0s 8ms/step - loss: 0.0247
# Epoch 20/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0245
# Epoch 21/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0243
# Epoch 22/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0241
# Epoch 23/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0238
# Epoch 24/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0236
# Epoch 25/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0234
# Epoch 26/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0232
# Epoch 27/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0230
# Epoch 28/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0228
# Epoch 29/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0226
# Epoch 30/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0224
# Epoch 31/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 32/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0220
# Epoch 33/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 34/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0216
# Epoch 35/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0213
# Epoch 36/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0211
# Epoch 37/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0209
# Epoch 38/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0207
# Epoch 39/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0205
# Epoch 40/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0202
# Epoch 41/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0200
# Epoch 42/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0200
# Epoch 43/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0195
# Epoch 44/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192
# Epoch 45/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0190
# Epoch 46/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0189
# Epoch 47/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0186
# Epoch 48/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0184
# Epoch 49/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0181
# Epoch 50/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0178
# Epoch 51/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0175
# Epoch 52/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0174
# Epoch 53/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0171
# Epoch 54/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0169
# Epoch 55/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0166
# Epoch 56/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0164
# Epoch 57/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0162
# Epoch 58/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0161
# Epoch 59/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157
# Epoch 60/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0157
# Epoch 61/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 62/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0151
# Epoch 63/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0148
# Epoch 64/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0147
# Epoch 65/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 66/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0143
# Epoch 67/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0141
# Epoch 68/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0143
# Epoch 69/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0137
# Epoch 70/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0137
# Epoch 71/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0136
# Epoch 72/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0133
# Epoch 73/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0131
# Epoch 74/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0130
# Epoch 75/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0130
# Epoch 76/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0126
# Epoch 77/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0126
# Epoch 78/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0124
# Epoch 79/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0126
# Epoch 80/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 81/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 82/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0120
# Epoch 83/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0119
# Epoch 84/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0118
# Epoch 85/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0115
# Epoch 86/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0113
# Epoch 87/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 88/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0111
# Epoch 89/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0110
# Epoch 90/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 91/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0107
# Epoch 92/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0108
# Epoch 93/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0104
# Epoch 94/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0103
# Epoch 95/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0102
# Epoch 96/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0101
# Epoch 97/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0100
# Epoch 98/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0099
# Epoch 99/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0098
# Epoch 100/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0099

# %%
y_pred = model.predict(X_test_t)
print("y_test: {}".format(y_test_))
print("y_pred: {}".format(y_pred))
# Out:
# y_test: [[0.57019947]
#  [0.54071679]
#  [0.500274  ]
#  [0.40387988]
#  [0.18182815]
#  [0.11327269]
#  [0.07414511]
#  [0.0316199 ]
#  [0.        ]]
# y_pred: [[0.698954  ]
#  [0.6721973 ]
#  [0.64555013]
#  [0.61931646]
#  [0.57900864]
#  [0.4901889 ]
#  [0.39310655]
#  [0.3002136 ]
#  [0.21437244]]

# %%
y_test.index #20년 11월~21년7월
# Out:
# DatetimeIndex(['2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01',
#                '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01',
#                '2021-07-01'],
#               dtype='datetime64[ns]', name='년월', freq=None)

# %%
y_pred = scaler.inverse_transform(y_pred)
y_test_ = scaler.inverse_transform(y_test_)

# %%
plt.figure(figsize=(10,10))
plt.plot(y_test.index,y_pred,label='예측값')
plt.plot(y_test.index,y_test_, label='원래값')
plt.title('송파구')
plt.xlabel('년도')
plt.legend()
plt.show()

# %%
#seocho = seocho.drop(columns='구',axis=1)
new_data = seocho

scaled_data = scaler.fit_transform(new_data)

def create_dataset(X, look_back=1):
    Xs = []
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        
    return np.array(Xs)
X_30 = create_dataset(scaled_data,10)
X_30.shape
len(new_data)
# Out:
# 88

# %%
def prediction(model):
    prediction = model.predict(X_30)
    prediction = scaler.inverse_transform(prediction)
    return prediction

forecast = prediction(model)

def plot_multi_step(history, prediction1):
    
    plt.figure(figsize=(15, 6))
    
    range_history = len(history)
    range_future = list(range(range_history, range_history + len(prediction1)))

    plt.plot(np.arange(range_history), np.array(history), label='실제값')
    plt.plot(range_future, np.array(prediction1),label='미래예측값')
    plt.xlabel('년월')
    plt.title('2020년 10월~2028년 1월 인구수(예측값 포함) 송파구')
    #plt.xlim(0,17)
    plt.axvline(x=87.4, color='r')
    plt.ylabel('인구 수')    
    
plot_multi_step(new_data, forecast)

# %%
#미래 데이터 개월 수
range_history = len(new_data)
len(list(range(range_history, range_history + len(forecast))))
# Out:
# 78
